# %% [markdown]
# <a href="https://colab.research.google.com/github/djferranti/RegularizedStokesletsTutorial/blob/main/flow_past_sphere_streamlines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# get the dependencies for pyvista
# only need to run this once
# !apt-get update
# !apt-get install -qq libgl1-mesa-glx
# !pip install -U pyvista -qq --quiet
# !pip install "pyvista[jupyter]" --quiet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
from reg_stokeslet_surfaces import *
grid, sphere, stream_tubes = test_drag_sphere_colab()
# Out:
# ************Triangle Data******************
# number of triangles = 320
# number of faces = 320
# number of DOF (3 times number of sphere vertices) = 486
# *******************************************
# Drag error data
# ell2 error = 0.10165692269245301
# relative error (%) = 0.5393066322490148
# average distance = 0.2776085844606615
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
#view streamlines from different vantage point
import pyvista as pv
plotter = pv.Plotter()
clim = [stream_tubes['speed'].min(), stream_tubes['speed'].max()]
arrows = grid.glyph(orient='vectors', scale='speed', factor=0.2)

plotter.add_mesh(sphere, color='lightgrey', opacity=1.0, show_edges=True)
plotter.add_mesh(stream_tubes, scalars="speed", cmap="viridis",
                            clim = clim,
                            scalar_bar_args={"title": "Speed", "vertical": True},
                            line_width=2)
plotter.add_mesh(arrows, color='black')  # white arrows on top
# Add axes
plotter.show_axes()  # Show XYZ triad
plotter.view_isometric()  # Or set custom view
plotter.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>
